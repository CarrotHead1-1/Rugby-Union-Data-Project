# %%
df = spark.read.csv("/https://dbc-423a5d50-03a6.cloud.databricks.com/editor/files/4469708316914440?o=684212911772223/matchResults2015-2018.csv", header = True, inferSchema = True)
df.show(5)
df.printSchema()
df.groupBy("HomeTeam").count().show()

df.select("HomeTeam", "AwayTeam", "HomeScore", "AwayScore").show(10)
