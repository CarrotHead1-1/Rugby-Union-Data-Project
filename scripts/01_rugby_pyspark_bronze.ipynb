# %%
#read data form unity catalog
df = spark.read.table("bronze_dev.default.match_results_2015_2018")

df.show(5)
df.printSchema()
df.groupby("HomeTeam").count().show()

df.select("HomeTeam","AwayTeam", "HomeScore", "AwayScore").show(10)
